# %%
from sqlalchemy import create_engine ;
import pandas as pd;

server = "DESKTOP-8RIE8TC/SQLEXPRESS" ;
database = "HospitalETL" ;
engine = create_engine(f"mssql+pyodbc://{server}/{database}?driver=ODBC+Driver+22+for+SQL+Server");
